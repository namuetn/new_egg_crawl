# %%
import pandas as pd

# %%
data = pd.read_csv('newegg100-1.csv')
data.head()
# Out:
#    branding                                             imgUrl  \
# 0  GIGABYTE  https://c1.neweggimages.com/ProductImageCompre...
# 1  GIGABYTE  https://c1.neweggimages.com/ProductImageCompre...
# 2    51Risc  https://c1.neweggimages.com/ProductImageCompre...
# 3  GIGABYTE  https://c1.neweggimages.com/ProductImageCompre...
# 4       XFX  https://c1.neweggimages.com/ProductImageCompre...
#
#            itemId    price  rating  ratingCount       shipping  \
# 0      14-932-580   849.99     4.9         55.0  Free Shipping
# 1      14-932-561  1219.99     4.3        107.0  Free Shipping
# 2  9SIB86XH2K2757    89.00     4.5         13.0  Free Shipping
# 3      14-932-562  1189.99     4.0         39.0  Free Shipping
# 4  9SIAD2CJS91325   779.99     4.2         20.0  Free Shipping
#
#                                                title
# 0  GIGABYTE GeForce RTX 4070 Ti GAMING OC 12G Gra...
# 1  GIGABYTE Gaming GeForce RTX 4080 16GB GDDR6X P...
# ...

# %%
data = data['itemId']

# %%
data.head()
# Out:
# 0        14-932-580
# 1        14-932-561
# 2    9SIB86XH2K2757
# 3        14-932-562
# 4    9SIAD2CJS91325
# Name: itemId, dtype: object

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data = list(data)

# %%
data
# Out:
# ['14-932-580',
#  '14-932-561',
#  '9SIB86XH2K2757',
#  '14-932-562',
#  '9SIAD2CJS91325',
#  '9SIBJP7JNN7312',
#  '14-137-765',
#  '9SIADFRJPN3889',
#  '9SIAZUEJM41519',
#  '9SIAD2CJFB5354',
#  '14-137-640',
#  '14-126-639',
#  '14-137-761',
#  '14-137-682',
#  '14-932-582',
#  '9SIAZUEFY85385',
#  '14-137-632',
#  '14-137-790',
#  '14-202-428',
#  '14-883-002',
#  '14-932-611',
#  '14-126-606',
#  '14-126-593',
#  '14-202-424',
#  '14-137-631',
#  '14-126-611',
#  '14-930-066',
#  '14-930-090',
#  '14-137-789',
#  '14-126-594',
#  '14-137-735',
#  '14-930-088',
#  '14-930-070',
#  '14-932-608',
#  '14-202-405',
#  '14-932-550',
#  '14-137-773',
#  '14-126-637',
#  '14-930-076',
#  '14-930-059',
#  '14-932-434',
#  '14-137-791',
#  '14-202-429',
#  '14-126-637',
#  '14-930-081',
#  '14-932-519',
#  '14-930-073',
#  '14-930-048',
#  '14-150-848',
#  '14-932-449',
#  '14-137-737',
#  '14-500-518',
#  '14-930-090',
#  '14-137-631',
#  '14-500-552',
#  '14-202-431',
#  '14-126-599',
# ...
